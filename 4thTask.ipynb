# %% [markdown]
# ## The Sparks Foundation
# ### Data Science and Buissness Analytics Internship
#
# * Muhammad Sameer
# * Task No: 4

# %%
import pandas as pd

# %%
df = pd.read_csv('globalterrorismdb_0718dist.csv', encoding='latin-1')
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_7640\3700301979.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('globalterrorismdb_0718dist.csv', encoding='latin-1')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# Display all column names
for column in df.columns:
    print(column)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# ...

# %%
# Select relevant columns
columns = ['country_txt', 'region_txt', 'provstate', 'city', 'latitude', 'longitude']
df_geo = df[columns]

# %%
# Count the number of terrorist incidents by country
country_counts = df_geo['country_txt'].value_counts()

# %%
# Count the number of terrorist incidents by region
region_counts = df_geo['region_txt'].value_counts()

# %%
# Count the number of terrorist incidents by state/province
state_counts = df_geo['provstate'].value_counts()

# %%
# Count the number of terrorist incidents by city
city_counts = df_geo['city'].value_counts()

# %%
# Print the top hot zones of terrorism
print("Top 10 countries with the highest number of terrorist incidents:")
print(country_counts.head(10))
# Out:
# Top 10 countries with the highest number of terrorist incidents:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: country_txt, dtype: int64

# %%
print("\nTop 10 regions with the highest number of terrorist incidents:")
print(region_counts.head(10))
# Out:
# Top 10 regions with the highest number of terrorist incidents:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Name: region_txt, dtype: int64

# %%
print("\nTop 10 states/provinces with the highest number of terrorist incidents:")
print(state_counts.head(10))
# Out:
# Top 10 states/provinces with the highest number of terrorist incidents:
# Baghdad               7645
# Northern Ireland      4498
# Unknown               4290
# Balochistan           3710
# Saladin               3411
# Al Anbar              3299
# Nineveh               3241
# Sindh                 3206
# Khyber Pakhtunkhwa    3084
# Diyala                3041
# Name: provstate, dtype: int64

# %%
print("\nTop 10 cities with the highest number of terrorist incidents:")
print(city_counts.head(10))
# Out:
# Top 10 cities with the highest number of terrorist incidents:
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Name: city, dtype: int64

# %%
# Select relevant columns
attack_columns = ['attacktype1_txt', 'attacktype2_txt']
weapon_columns = ['weaptype1_txt', 'weaptype2_txt']

# %%
# Combine attack and weapon columns
columns = attack_columns + weapon_columns

# %%
# Create a subset of the dataset with selected columns
df_attack_weapon = df[columns]

# %%
# Count the number of occurrences for each attack type
attack_counts = df_attack_weapon['attacktype1_txt'].value_counts()

# %%
# Count the number of occurrences for each weapon type
weapon_counts = df_attack_weapon['weaptype1_txt'].value_counts()

# %%
# Print the most common attack types
print("Most common attack types:")
print(attack_counts)
# Out:
# Most common attack types:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
# Print the most common weapon types
print("\nMost common weapon types:")
print(weapon_counts)
# Out:
# Most common weapon types:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# ...

# %%
# Select relevant columns
target_columns = ['targtype1_txt', 'targsubtype1_txt', 'target1']

# %%
# Create a subset of the dataset with selected columns
df_targets = df[target_columns]

# %%
# Count the number of occurrences for each target type
target_type_counts = df_targets['targtype1_txt'].value_counts()

# %%
# Count the number of occurrences for each target subtype
target_subtype_counts = df_targets['targsubtype1_txt'].value_counts()

# %%
# Count the number of occurrences for each target subtype
target_subtype_counts = df_targets['targsubtype1_txt'].value_counts()

# %%
# Print the most common target types
print("Most common target types:")
print(target_type_counts)
# Out:
# Most common target types:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: targtype1_txt, dtype: int64

# %%
# Count the number of occurrences for each specific target
specific_target_counts = df_targets['target1'].value_counts()

# %%
# Print the most common target subtypes
print("\nMost common target subtypes:")
print(target_subtype_counts)
# Out:
# Most common target subtypes:
# Unnamed Civilian/Unspecified                               11596
# Police Security Forces/Officers                            11178
# Military Unit/Patrol/Convoy                                 8277
# Military Personnel (soldiers, troops, officers, forces)     7963
# Government Personnel (excluding police, military)           6610
#                                                            ...
# Multiple Telecommunication Targets                            31
# Fire Fighter/Truck                                            27
# Personnel                                                     19
# Oil Tanker                                                    19
# Internet Infrastructure                                       12
# Name: targsubtype1_txt, Length: 112, dtype: int64

# %%
# Print the most common specific targets
print("\nMost common specific targets:")
print(specific_target_counts)
# Out:
# Most common specific targets:
# Civilians                  6461
# Unknown                    5918
# Soldiers                   3157
# Patrol                     2942
# Checkpoint                 2905
#                            ...
# Manager Sanat Raj             1
# Military/ Police patrol       1
# Thor 67 Outpost               1
# Employee's Vehicle            1
# Hmeymim Air Base              1
# Name: target1, Length: 86006, dtype: int64

# %%
# Select relevant columns
motive_columns = ['motive']
claim_columns = ['claimed', 'claimmode_txt']

# %%
# Combine motive and claim columns
columns = motive_columns + claim_columns

# %%
# Create a subset of the dataset with selected columns
df_motives_claims = df[columns]

# %%
# Count the number of occurrences for each motive
motive_counts = df_motives_claims['motive'].value_counts()

# %%
# Count the number of occurrences for each claim status
claim_status_counts = df_motives_claims['claimed'].value_counts()

# %%
# Count the number of occurrences for each claim mode
claim_mode_counts = df_motives_claims['claimmode_txt'].value_counts()

# %%
# Print the most common motives
print("Most common motives:")
print(motive_counts)
# Out:
# Most common motives:
# Unknown                                                                                                                                                                                                                                                                                                                                                                  14889
# The specific motive for the attack is unknown.                                                                                                                                                                                                                                                                                                                           14430
# ...

# %%
# Print the claim status counts
print("\nClaim status counts:")
print(claim_status_counts)
# Out:
# Claim status counts:
#  0.0    95091
#  1.0    19006
# -9.0     1474
# Name: claimed, dtype: int64

# %%
# Print the claim mode counts
print("\nClaim mode counts:")
print(claim_mode_counts)
# Out:
# Claim mode counts:
# Personal claim                   5207
# Posted to website, blog, etc.    4506
# Unknown                          3977
# Call (post-incident)             1780
# Note left at scene               1212
# E-mail                           1076
# Other                             459
# Video                             354
# Letter                            333
# Call (pre-incident)               179
# Name: claimmode_txt, dtype: int64

# %% [markdown]
# ## DATA VISUALIZATION

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Plotting histograms using Seaborn
plt.figure(figsize=(12, 8))

# %%
plt.subplot(2, 2, 1)
sns.histplot(country_counts, bins=len(country_counts), kde=True)
plt.title('Top 10 Countries with the Highest Number of Terrorist Incidents')
# Out:
# Text(0.5, 1.0, 'Top 10 Countries with the Highest Number of Terrorist Incidents')

# %%
plt.subplot(2, 2, 2)
sns.histplot(region_counts, bins=len(region_counts), kde=True)
plt.title('Top 10 Regions with the Highest Number of Terrorist Incidents')
# Out:
# Text(0.5, 1.0, 'Top 10 Regions with the Highest Number of Terrorist Incidents')

# %%
plt.subplot(2, 2, 3)
sns.histplot(state_counts, bins=len(state_counts), kde=True)
plt.title('Top 10 States/Provinces with the Highest Number of Terrorist Incidents')
# Out:
# Text(0.5, 1.0, 'Top 10 States/Provinces with the Highest Number of Terrorist Incidents')

# %%
# Plotting bar charts using Seaborn
plt.figure(figsize=(12, 6))

# %%
plt.subplot(1, 2, 1)
sns.barplot(x=attack_counts.values, y=attack_counts.index, color='b')
plt.xlabel('Count')
plt.ylabel('Attack Type')
plt.title('Most Common Attack Types')
# Out:
# Text(0.5, 1.0, 'Most Common Attack Types')

# %%
plt.subplot(1, 2, 2)
sns.barplot(x=weapon_counts.values, y=weapon_counts.index, color='g')
plt.xlabel('Count')
plt.ylabel('Weapon Type')
plt.title('Most Common Weapon Types')

plt.tight_layout()
plt.show()

# %%
# Plot the most common target types as a pie chart
plt.figure(figsize=(8, 6))
target_type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Target Types')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# Plot the most common target subtypes as a pie chart
plt.figure(figsize=(8, 6))
target_subtype_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Target Subtypes')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# Plot the most common specific targets as a pie chart
plt.figure(figsize=(10, 8))
specific_target_counts.head(10).plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Specific Targets')
plt.ylabel('')

plt.show()
